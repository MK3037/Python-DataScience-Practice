# %% [markdown]
# # Probability and Probability Distribution

# %% [markdown]
# - The scipy.stats is the SciPy sub-package. It is mainly used for probabilistic distributions and statistical operations. There is a wide range of probability functions.
# - There are three classes:
#  - Class   Description
#     - rv_continuous- For continuous random variables, we can create specialized distribution subclasses and instances.
#     - rv_discrete- 	For discrete random variables, we can create specialized distribution subclasses and instances.
#     - rv_histogram- generate specific distribution histograms.

# %% [markdown]
# ## Discrete Distributions

# %% [markdown]
# ### Consider the following distributions:
# * __Bernoulli__
# * __Binomial__
# * __Poisson__

# %% [markdown]
# ### Bernoulli Distribution in Python
# You can generate a bernoulli distributed discrete random variable using scipy.stats module's bernoulli.rvs() method which takes $p$ (probability of success) as a shape parameter. To shift distribution use the loc parameter. size decides the number of times to repeat the trials. If you want to maintain reproducibility, include a random_state argument assigned to a number.

# %%
import seaborn as sns
from scipy.stats import bernoulli
data_bern = bernoulli.rvs(size=10000,p=0.6)

# %%
ax= sns.distplot(data_bern,
                 kde=True,
                 color="skyblue",
                 hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Bernoulli Distribution', ylabel='Frequency')
# Out:
# /tmp/ipython-input-2883798624.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(data_bern,
# [Text(0.5, 0, 'Bernoulli Distribution'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# ### Binomial Distribution
# The binomial distribution is used to model the number of successes with repeated trial where each trial can either result in “success” or “failure”, the probability of success stays the same from one trial to another, the trials are independent of one another and finally the number of trials is fixed in advanced. A typical example is a fixed number of coin tosses. Here is how we get binomial distribution objects in scipy and generate some random numbers:
# - <font color=blue>rvs(n, p, loc=0, size=1)	Random variates.</font>
# - <font color=blue>pmf(x, n, p, loc=0)	Probability mass function.</font>

# %%
from scipy import stats
import numpy as np

# %% [markdown]
# **_random_state=143_** is just so that the results are reproducible. If you include this, this result will always be the same. If you want to repeat and get different results, just omit this

# %%
binomial=stats.binom(n=10,p=0.4)
print(binomial)
binomial.rvs(size=10,random_state=143)
# Out:
# ...
# array([5, 3, 4, 4, 4, 6, 1, 1, 3, 2])

# %%
print(binomial.pmf(2))
print(binomial.pmf([2,3,4]))
# Out:
# 0.12093235199999991
# [0.12093235 0.21499085 0.25082266]

# %%
from scipy.stats import binom
# setting the values
# of n and p
n = 6
p = 0.6
# defining the list of r values
r_values = list(range(n + 1))

# obtaining the mean and variance
mean, var = binom.stats(n, p)
# list of pmf values
dist = [binom.pmf(r, n, p) for r in r_values ]

# printing the table
#print("r\tp(r)")
for i in range(n + 1):
    print(str(r_values[i]) + "\t" + str(dist[i]))
# printing mean and variance
print("mean = "+str(mean))
print("variance = "+str(var))
# Out:
# 0	0.0040960000000000015
# 1	0.03686400000000002
# 2	0.1382400000000001
# 3	0.2764800000000001
# 4	0.3110400000000001
# 5	0.1866240000000001
# 6	0.04665599999999999
# mean = 3.5999999999999996
# variance = 1.44

# %%
from scipy.stats import binom
import matplotlib.pyplot as plt
# setting the values
# of n and p
n = 6
p = 0.6
# defining list of r values
r_values = list(range(n + 1))
# list of pmf values
dist = [binom.pmf(r, n, p) for r in r_values ]
# plotting the graph
plt.bar(r_values, dist)
plt.show()

# %%
plt.scatter(r_values,dist,label="PMF",color="Orange")
plt.title("Binomial Distribution")
plt.ylabel("Density")
plt.legend()
plt.xticks(r_values)
plt.show()

# %% [markdown]
# Now we will generate 1000 random numbers from this distribution binomial_sample=binomial.rvs(size=1000,random_state=143)and create a histogram. Since we are dealing with discrete numbers, we have to add some options to control how the histogram is calculated:
#
# - bins=11 to make sure we have 11 bins, one for each number 0,1,…,10
# - range=(0,11) to make sure the respective classes are [0,1), [1,2), …, [10,11)
# - align='left' to make sure that the bar is aligned with the PMF (you’ll see why later when we overlay everything.
# - rwidth=0.75 so the bars of the histogram are 75% of the class width. This will make sure the bars don’t touch to communicate that we are working with discrete data.
# - alpha=0.75 so that the bars are semi-transparent to allow the overlay to look nice.

# %%
t=np.arange(0,11)
binomial_sample=binomial.rvs(size=1000,random_state=143)
plt.hist(binomial_sample,bins=11,range=(0,11),density=True,align='left',rwidth=0.75,label="Sample",alpha=0.50)
plt.title("Binomial Distribution")
plt.ylabel("Density")
plt.legend()
plt.xticks(t)
plt.show()

# %% [markdown]
# ### The Poisson distribution is very commonly used in practice as well. It is used to model the number of events (say car accidents) occurs in a fixed duration of time (or space). The values this random variable can take are 0,1,2,… (it goes on forever). In scipy we can set up a Poisson distribution object by stats.poisson(mu=2) . Generating random numbers is just like the other distributions:

# %% [markdown]
# - **A Poisson distribution is a kind of probability distribution used in statistics to illustrate how many times an event is expected to happen over a certain amount of time.**
# - It’s also called count distribution. np.random.poisson function() is used to create data for poisson distribution. lam refers to The number of occurrences that are expected to occur in a given time frame.
# - In this example, we can take the condition as “if a student studies for 5 hours a day, the probability that he’ll study 6 hours a day is?.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# generate poisson data
poisson_data = np.random.poisson(lam=5, size=1000)

# plotting a histogram
ax = sns.distplot(poisson_data,
                  kde=True,
                  color='blue')
ax.set(xlabel='Poisson Distribution', ylabel='Frequency')

plt.show()
# Out:
# /tmp/ipython-input-3877490209.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(poisson_data,

# %% [markdown]
# - __kdebool__
# If True, compute a kernel density estimate to smooth the distribution and show on the plot as (one or more) line(s). Only relevant with univariate data.

# %%
fig, ax = plt.subplots(1, 1)
# Expected number of times the event occurs in a given interval
mu = 3
# get the different number of times the event may occur
x = np.arange(stats.poisson.ppf(0.01, mu),
              stats.poisson.ppf(0.9999, mu))
# get the pmf from the poisson distribution
y = stats.poisson.pmf(x, mu)
# plot the probability
ax.plot(x, y, 'bo')
# add verticle lines for better visualization
ax.vlines(x, 0, y)
ax.set_title("Probability")
ax.set_xlabel("No. of cars passing through the toll gate every 5 mins")
plt.show()

# %% [markdown]
# ## Continuous Distributions

# %% [markdown]
# ### We will start with the arguably the most famous distribution: Normal (Gaussian) distribution.

# %% [markdown]
# We start with creating an insmtance of the stats.norm class and initialize this object to have mean 100 and standard deviation 15:

# %% [markdown]
# ### Normal distribution using numpy

# %%
import numpy as np
import matplotlib.pyplot as plt

# Mean of the distribution
Mean = 100

# satndard deviation of the distribution
Standard_deviation  = 5

# size
size = 100000

# creating a normal distribution data
values = np.random.normal(Mean, Standard_deviation, size)

# plotting histograph for given bins
plt.hist(values,100)
# plotting mean line
plt.axvline(values.mean(), color='k', linestyle='dashed', linewidth=2)
plt.show()

# %% [markdown]
# ### Normal distribution using scipy

# %% [markdown]
# You can generate a normally distributed random variable using scipy.stats module's norm.rvs() method. The loc argument corresponds to the mean of the distribution. scale corresponds to standard deviation and size to the number of random variates. If you want to maintain reproducibility, include a random_state argument assigned to a number.

# %%
from matplotlib import pyplot
from numpy.random import normal
from numpy import mean
from numpy import std
from scipy.stats import norm
sample = norm.rvs(size=10000,loc=0,scale=1)
pyplot.hist(sample,bins=10)
pyplot.show()

# %% [markdown]
# ### Uniform Distribution in Python
# Perhaps one of the simplest and useful distribution is the uniform distribution. The probability distribution function of the continuous uniform distribution is:

# %% [markdown]
# *bold text*![1.png](attachment:1.png)

# %% [markdown]
# Since any interval of numbers of equal width has an equal probability of being observed, the curve describing the distribution is a rectangle, with constant height across the interval and 0 height elsewhere. Since the area under the curve must be equal to 1, the length of the interval determines the height of the curve.

# %% [markdown]
# __You can visualize uniform distribution in python with the help of a random number generator acting over an interval of numbers (a,b). You need to import the uniform function from scipy.stats module.__

# %% [markdown]
# The uniform function generates a uniform continuous variable between the specified interval via its loc and scale arguments. This distribution is constant between loc and loc + scale. The size arguments describe the number of random variates. If you want to maintain reproducibility, include a random_state argument assigned to a number.

# %%
# random numbers from uniform distribution
from scipy.stats import uniform
n = 10000
start = 10
width = 20
data_uniform = uniform.rvs(size=n, loc = start, scale=width)

# %%
# Out:
# /tmp/ipython-input-3020480515.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(data_uniform,
# [Text(0.5, 0, 'Uniform Distribution '), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# ### Exponential Distribution in Python

# %% [markdown]
# - You can generate an exponentially distributed random variable using scipy.stats module's expon.rvs() method which takes shape parameter scale as its argument which is nothing but 1/lambda in the equation.
# - To shift distribution use the loc argument, size decides the number of random variates in the distribution. If you want to maintain reproducibility, include a random_state argument assigned to a number.

# %%
from scipy.stats import expon
data_expon = expon.rvs(scale=1,loc=0,size=1000)

# %%
ax = sns.distplot(data_expon,
                  kde=True,
                  bins=100,
                  color='skyblue',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Exponential Distribution', ylabel='Frequency')
# Out:
# C:\Users\gcet\AppData\Local\Temp\ipykernel_6524\2396102876.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(data_expon,
# [Text(0.5, 0, 'Exponential Distribution'), Text(0, 0.5, 'Frequency')]
